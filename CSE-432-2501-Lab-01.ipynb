# %% [markdown]
# # Task 1
# Generating simnple Discrete Time Signal

# %%
import numpy as np
import matplotlib.pyplot as mpl
x=[2,5,1,5,6,8,0,5,6,7,1,3]
n=np.arange(-4,8,1)
print(x)
mpl.stem(n,x)
# Out:
# [2, 5, 1, 5, 6, 8, 0, 5, 6, 7, 1, 3]
# <StemContainer object of 3 artists>

# %% [markdown]
# # Task 2
# Generating Continuous Time Signal

# %%
import numpy as np
import matplotlib.pyplot as mpl
n=np.arange(0,6*np.pi,0.01)
x=np.sin(n)
mpl.plot(n,x)
print(len(n))
# Out:
# 1885

# %% [markdown]
# # Task 3
# Decorating Plots

# %%
import numpy as np
import matplotlib.pyplot as mpl
n=np.arange(0,6*np.pi,0.01)
x=np.sin(n)
y=np.cos(n)
mpl.plot(n,x, color='red')
mpl.plot(n,y, color='yellow')
mpl.title("Sine and Cosine curves")
mpl.xlabel("n")
mpl.ylabel("Values")
mpl.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Task 4
# Plotting multiple signals using subplots.

# %%
import numpy as np
import matplotlib.pyplot as mpl
n=np.arange(0,6*np.pi,0.01)
x=np.sin(n)
y=np.cos(n)
fig, ax = mpl.subplots(1,2)
mpl.subplot(1,2,1)
mpl.plot(n,x, color='red')
mpl.title("Sine Curve")
mpl.subplot(1,2,2)
mpl.plot(n,y, color='yellow')
mpl.title("Cosine Curve")
mpl.suptitle("Sine and Cosine Curves")
mpl.show
fig.tight_layout()
